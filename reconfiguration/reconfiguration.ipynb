# %% [markdown]
# **It is not _really_ necessary for you to use python or jupyter notebook for this challenge. You could simply use excel and plot the .CSV data as a scatter plot to get the flag.**

# %% [markdown]
# **1. Open Excel**

# %% [markdown]
# **2. Highlight the data**

# %% [markdown]
# **3. In the Instert tab, click on Scatter**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **૮₍˶ •. • ⑅₎ა ♡ glockachu**
